# %%
import numpy as np
import pandas as pd

# %%
print('saya')
# Out:
# saya

# %%
df = pd.read_csv('Data Penjualan Warmindo.csv')
df.head()
# Out:
#    id  invoice_id tanggal_transaksi  customer_id   nama_pelanggan  \
# 0   1           1           4/11/22           44      Mira Rosita
# 1   2           1           4/11/22           44      Mira Rosita
# 2   3           2            8/1/22           10         Tia Sari
# 3   4           3            4/3/22           62  Anisa Rahmawati
# 4   5           3            4/3/22           14      Rika Kurnia
#
#   jenis_kelamin  umur_pelanggan  product_id  quantity jenis_pembayaran  \
# 0             F              24           2         2         QRIS-OVO
# 1             F              24          19         2         QRIS-OVO
# 2             F              22           2         2             CASH
# 3             F              31          15         1      QRIS-OTHERS
# 4             F              26          23         2      QRIS-OTHERS
#
#   jenis_pesanan               nama_produk kategori_produk jenis_produk  \
# ...

# %%
df.tail()
# Out:
#         id  invoice_id tanggal_transaksi  customer_id   nama_pelanggan  \
# 1994  1996        1497           4/14/22           62  Anisa Rahmawati
# 1995  1997        1498           8/12/22            7    Harry Prabowo
# 1996  1998        1499           3/19/22           12  Yanti Wulandari
# 1997  1999        1500            4/8/22           62  Anisa Rahmawati
# 1998  2000        1500            4/8/22           62  Anisa Rahmawati
#
#      jenis_kelamin  umur_pelanggan  product_id  quantity jenis_pembayaran  \
# 1994             F              31          12         3      QRIS-OTHERS
# 1995             M              42          13         2         QRIS-OVO
# 1996             F              30           6         3      QRIS-OTHERS
# 1997             F              31          13         3             CASH
# 1998             F              31          19         2             CASH
#
#      jenis_pesanan                    nama_produk kategori_produk  \
# ...
